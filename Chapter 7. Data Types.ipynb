# %%
import pandas as pd
import seaborn as sns

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %% [markdown]
# This chapter outcome:
# - Convert to string
# - Convert to numeric
# - Convert to category

# %% [markdown]
# To convert data type from one to another, we use __astype()__

# %% [markdown]
# We can only use astype() on __Series__

# %% [markdown]
# Therefore, select __a column__ that want to be converted with astype() function

# %% [markdown]
# # 1. Convert to String

# %%
# Change color column from category to string
diamonds['color'] = diamonds['color'].astype(str)

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color        object
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %% [markdown]
# As you can see, now the cut_str column is __object type__

# %% [markdown]
# # 2. Convert to Numeric

# %% [markdown]
# - Convert to numeric can also be used with astype()
# - The problem arise when a column with number data in __string__ contain __missing values__

# %% [markdown]
# Example

# %%
diamonds_sub_missing = diamonds.copy()

# %%
# Change carat dtype into 'str'
diamonds_sub_missing['carat'] = diamonds_sub_missing['carat'].astype('str')

# %%
# DOuble check dtypes all columns
diamonds_sub_missing.dtypes
# Out:
# carat        object
# cut        category
# color        object
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
diamonds_sub_missing.loc[[1,4,9,13,15], 'carat'] = 'missing'

# %%
diamonds_sub_missing.head(20)
# Out:
#       carat        cut color clarity  depth  table  price     x     y     z
# 0      0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   missing    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   missing       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5      0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6      0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7      0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8      0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   missing  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.3       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11     0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12     0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13  missing      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14      0.2    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15  missing    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16      0.3      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17      0.3       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18      0.3       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19      0.3  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66

# %%
# As you can see, astype() cannot convert 'missing' into numeric. Thus it throws error
diamonds_sub_missing['carat'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1328/2083163818.py in <module>
#       1 # As you can see, astype() cannot convert 'missing' into numeric. Thus it throws error
# ----> 2 diamonds_sub_missing['carat'].astype('float')
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\envs\ds\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'missing'

# %% [markdown]
# To solve this problem, we will be using __pd.to_numeric ( data column , errors = ' coerce ' )__

# %%
diamonds_sub_missing['carat'] = pd.to_numeric(diamonds_sub_missing['carat'], errors='coerce')

# %%
# Now you can see the carat dtype is back to float
diamonds_sub_missing.dtypes
# Out:
# carat       float64
# cut        category
# color        object
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
# The 'missing' is converted into NaN
diamonds_sub_missing.head(20)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     NaN    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     NaN       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9     NaN  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13    NaN      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14   0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15    NaN    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16   0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17   0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18   0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19   0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66

# %% [markdown]
# # 3. Convert to Category

# %% [markdown]
# Convert data into category when:
# - data takes on limited, and usually fixed, number of possible values
#     - examples are gender, social class, blood type, country affiliation, observation time or rating via Likert scales
# - data might have an order (e.g. ‘strongly agree’ vs ‘agree’ or ‘first observation’ vs. ‘second observation’)
# - data takes a lot of memory

# %% [markdown]
# __Convert to category are NOT SO IMPORTANT, so don't think too much about it__

# %%
diamonds['color'] = diamonds['color'].astype('category')

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object
